# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv(r"H:\Python pr\Movie Prediction\IMDB-Movie-Data.csv")

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.isnull().sum()
#dropping would impact the data accuracy
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
print(data)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# here are some problem statements using the given movie dataset:
#
# <h3>Genre Impact on Rating:</h3>
#
# Problem Statement: "Is there a significant difference in the average ratings of Action movies and Drama movies?"
#
# <h3>Director's Influence on Revenue:</h3>
#
# Problem Statement: "Does the choice of director have a statistically significant impact on a movie's revenue?"
# Actor Popularity and Rating:
#
# Problem Statement: "Is there a relationship between the popularity of the lead actor in a movie and its average rating?"
# Year and Metascore Correlation:
#
# Problem Statement: "Is there a correlation between the year a movie was released and its Metascore?"
# Runtime and Revenue Relationship:
#
# Problem Statement: "Do longer runtime movies tend to generate more revenue than shorter runtime movies?"
# Rating and Revenue Association:
#
# Problem Statement: "Is there a significant positive association between a movie's rating and its revenue?"
# Genre's Effect on Metascore:
#
# Problem Statement: "Does the genre of a movie have a noticeable effect on its Metascore?"
# Year and Rating Trends:
#
# Problem Statement: "Are the average ratings of movies consistent across different years?"
# Director's Impact on Metascore:
#
# Problem Statement: "Does the director of a movie contribute to its Metascore?"
# Actor Popularity and Votes Relationship:
#
# Problem Statement: "Is there a correlation between the popularity of lead actors and the number of votes their movies receive?"
# Genre's Impact on Revenue:
#
# Problem Statement: "Do certain movie genres tend to generate more revenue than others?"
# Metascore and Rating Agreement:
#
# Problem Statement: "Is there agreement between a movie's Metascore and its user-generated rating?"

# %% [markdown]
# <h1>Statements</h1>
#
# Genre vs. Rating:
#
# "Movies of different genres have varying average ratings."
# "The average rating of Action movies is different from that of Comedy movies."
#
# Director's Impact on Rating:
#
# "Movies directed by different directors have different average ratings."
# "There is a significant difference in the average ratings of movies directed by Director A and Director B."
#
# Actor Influence on Revenue:
#
# "Movies featuring different actors have varying revenue."
# "The presence of Actor X leads to higher revenue compared to movies without Actor X."
#
# Year and Metascore:
#
# "There is a correlation between the year a movie was released and its Metascore."
# "Newer movies tend to have higher Metascores than older movies."
#
# Runtime and Rating:
#
# "There is a relationship between the runtime of a movie and its rating."
# "Movies with longer runtimes generally have higher ratings."
#
# Rating and Revenue:
#
# "There is a positive correlation between the rating of a movie and its revenue."
# "Higher-rated movies tend to generate more revenue."
#
# Genre and Metascore:
#
# "Different movie genres receive varying Metascores."
# "Certain genres, such as Drama, tend to have higher Metascores compared to others."
#
# Year and Rating:
#
# "The average rating of movies varies across different years."
# "Movies released in recent years have higher average ratings."
#
# Director's Impact on Revenue:
#
# "The director of a movie influences its revenue."
# "Movies directed by Director Y tend to generate more revenue than movies directed by Director Z."
#
# Actor Popularity and Votes:
#
# "The popularity of actors is correlated with the number of votes a movie receives."
# "Movies featuring highly popular actors receive more votes on average."
#
# Genre and Revenue:
#
# "The genre of a movie is related to its revenue generation."
# "Adventure movies tend to generate higher revenue than Romantic comedies."
#
# Metascore and Rating:
#
# "There is a positive correlation between a movie's Metascore and its rating."
# "Movies with higher Metascores tend to have higher ratings."

# %%
genreList=data.Genre.str.split(',')
genreList
# Out:
# 0       [Action, Adventure, Sci-Fi]
# 1      [Adventure, Mystery, Sci-Fi]
# 2                [Horror, Thriller]
# 3       [Animation, Comedy, Family]
# 4      [Action, Adventure, Fantasy]
#                    ...
# 995         [Crime, Drama, Mystery]
# 996                        [Horror]
# 997         [Drama, Music, Romance]
# 998             [Adventure, Comedy]
# 999       [Comedy, Family, Fantasy]
# Name: Genre, Length: 1000, dtype: object

# %%
data[:500].describe()
# Out:
#              Rank         Year  Runtime (Minutes)      Rating         Votes  \
# count  500.000000   500.000000         500.000000  500.000000  5.000000e+02
# mean   250.500000  2013.426000         116.510000    6.914600  2.168929e+05
# std    144.481833     3.025033          19.679748    0.923836  2.298131e+05
# min      1.000000  2006.000000          73.000000    2.700000  6.100000e+01
# 25%    125.750000  2012.000000         102.000000    6.300000  4.815150e+04
# 50%    250.500000  2015.000000         114.000000    7.000000  1.414500e+05
# 75%    375.250000  2016.000000         128.000000    7.600000  3.322945e+05
# max    500.000000  2016.000000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          448.000000  472.000000
# mean           106.066138   61.851695
# std            121.806796   16.938356
# min              0.000000   16.000000
# 25%             19.990000   50.000000
# 50%             63.440000   64.000000
# ...

# %%
data[500:].describe()
# Out:
#               Rank         Year  Runtime (Minutes)      Rating         Votes  \
# count   500.000000   500.000000         500.000000  500.000000     500.00000
# mean    750.500000  2012.140000         109.834000    6.531800  122723.58200
# std     144.481833     3.255395          17.285486    0.928749  118647.41164
# min     501.000000  2006.000000          66.000000    1.900000     173.00000
# 25%     625.750000  2009.750000          97.000000    6.100000   27033.00000
# 50%     750.500000  2013.000000         108.000000    6.600000   91880.00000
# 75%     875.250000  2015.000000         119.000000    7.200000  182131.75000
# max    1000.000000  2016.000000         191.000000    8.500000  776897.00000
#
#        Revenue (Millions)   Metascore
# count          424.000000  464.000000
# mean            58.538514   56.068966
# std             71.489270   16.979456
# min              0.010000   11.000000
# 25%              7.122500   43.000000
# 50%             37.145000   56.500000
# ...

# %%
data.describe({0.2,0.5,0.65,0.75}).transpose()
# Out:
#                      count           mean            std     min        20%  \
# Rank                1000.0     500.500000     288.819436     1.0    200.800
# Year                1000.0    2012.783000       3.205962  2006.0   2009.800
# Runtime (Minutes)   1000.0     113.172000      18.810908    66.0     97.000
# Rating              1000.0       6.723200       0.945429     1.9      6.000
# Votes               1000.0  169808.255000  188762.647518    61.0  26088.800
# Revenue (Millions)   872.0      82.956376     103.253540     0.0      7.268
# Metascore            936.0      58.985043      17.194757    11.0     43.000
#
#                            50%          65%         75%         max
# Rank                   500.500     650.3500     750.250     1000.00
# Year                  2014.000    2015.0000    2016.000     2016.00
# Runtime (Minutes)      111.000     118.0000     123.000      191.00
# Rating                   6.800       7.1000       7.400        9.00
# ...

# %%
data['Revenue (Millions)'].max()
# Out:
# 936.63

# %%
data.corr()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_9076\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.271592 -0.126790           0.267953  0.217654  0.639661
# Metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
#
#                     Revenue (Millions)  Metascore
# ...

# %% [markdown]
# histogram: distribution
# spread plot: for trend and comparison
