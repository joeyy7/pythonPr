# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. How do you load the IMDb dataset into a pandas DataFrame

data=pd.read_csv(r"H:\Python pr\Movie Prediction\IMDB-Movie-Data.csv")

# %%
# 2. Display the first 5 rows of the dataset. What information can you gather from these rows?

data[:5]
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# histogram: continuous data for distribution
# spread plot: for trend and comparison
# bar graph : discrete and continuous for comparison
# pie : for distribution and share visual
# box : to see outliers

# %%
data.plot(kind='bar', x='Rating', y='Revenue (Millions)',figsize=(10,5))
# Out:
# <Axes: xlabel='Rating'>

# %%
# 3. What method would you use to get an overview of column data types and missing values.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
marks1=[10,20,40,30,50,60,55,88,99,100]
time1=[30,60,140,120,160,170,200,50,350,450]

marks2=[40,50,60,100,70,60,55,20,10,5]
time2=[50,60,120,150,180,120,60,50,20,10]

plt.plot(marks1,time1)

plt.plot(marks2,time2)
plt.subplot(1,2,2)
plt.ylabel("Time")
plt.xlabel("Marks")
plt.show()

plt.subplot(12)
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_13852\1329481748.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 11
#       9 plt.plot(marks2,time2)
#      10 plt.subplot(1,2,2)
# ---> 11 plt.ylabel("Time")
#      12 plt.xlabel("Marks")
#      13 plt.show()
#
# TypeError: 'str' object is not callable

# %%
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y,'tab:red')

x = np.array([0, 1, 2, 3])
y = np.array([2,5, 3, 8])

plt.subplot(2, 2, 3)
plt.plot(x,y,'tab:green')

x = np.array([0, 1, 2, 3])
y = np.array([20,44, 69, 8])

plt.subplot(2, 2, 4)
plt.plot(x,y,'tab:purple')

plt.show()
