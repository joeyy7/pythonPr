# %%
import pandas as pd
import matplotlib.pylab as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv(r"H:\Python pr\advertising\advertising.csv")
print(data)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'TV'}>,
#         <Axes: title={'center': 'Radio'}>],
#        [<Axes: title={'center': 'Newspaper'}>,
#         <Axes: title={'center': 'Sales'}>]], dtype=object)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data['TV'].value_counts().sort_index().plot(kind='line')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
data['Radio'].plot(kind='line')
plt.xlabel('Radio')
plt.ylabel('Sales (in million)')
plt.show()

# %%
data['Newspaper'].plot(kind='line',figsize=(10,10))
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.show()

# %%
x=data['Radio']
y=data['Sales']
plt.scatter(x,y)

# %%
x=data['TV']
y=data['Sales']
plt.scatter(x,y)

# %%
x=data['Newspaper']
y=data['Sales']
plt.scatter(x,y)

# %%
x=data['Radio']      #blue define relation b/w radio and sales
y=data['Sales']
plt.scatter(x,y)
x=data['TV']        #orange define relation b/w TV and sales
y=data['Sales']
plt.scatter(x,y)
x=data['Newspaper']  #green  define relation b/w Newspaper and sales
y=data['Sales']
plt.scatter(x,y)

# %%
x=data['Newspaper']
y=data['TV']
plt.scatter(x,y)
x=data['Newspaper']
y=data['Radio']
plt.scatter(x,y)

# %%
x=data['TV']       # blue
y=data['Radio']
plt.scatter(x,y)
x=data['TV']           #ornge
y=data['Newspaper']
plt.scatter(x,y)

# %%
x=data['Radio']         # poor relation
y=data['Sales']
plt.subplot(2, 2, 1)
plt.scatter(x,y)
x=data['TV']            # depend on TV and Sales beacause It is highly correclated
y=data['Sales']
plt.subplot(2,2,2)
plt.scatter(x,y)
x=data['Newspaper']      # worst relation
y=data['Sales']
plt.subplot(2, 2, 3)
plt.scatter(x,y)

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
reg = LinearRegression()
reg.fit(data[['TV']],data['Sales'])
# Out:
# LinearRegression()

# %%
reg.predict([[236]])
# Out:
# c:\Users\a\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.06450732])

# %%
x=data['TV']
y=data['Sales']
plt.scatter(x,y)
plt.plot(data["TV"],reg.predict(data[["TV"]]),color='black')

# %%
tv_train,tv_test,sales_train,sales_test=train_test_split(data[["TV"]],data["Sales"],test_size=0.25,random_state=650)

# %%
tv_test
# Out:
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3
# 115   75.1
# 69   216.8
# 170   50.0
# 174  222.4
# 45   175.1
# 66    31.5
# 182   56.2
# 165  234.5
# 78     5.4
# 186  139.5
# 177  170.2
# 56     7.3
# 152  197.6
# 82    75.3
# 68   237.4
# 124  229.5
# 16    67.8
# 148   38.0
# 93   250.9
# 65    69.0
# 60    53.5
# 84   213.5
# 67   139.3
# 125   87.2
# 132    8.4
# 9    199.8
# 18    69.2
# 55   198.9
# 75    16.9
# 150  280.7
# 104  238.2
# 135   48.3
# 137  273.7
# 164  117.2
# 76    27.5
# 79   116.0
# 197  177.0
# 38    43.1
# 24    62.3
# 122  224.0
# 195   38.2
# 29    70.6
# 19   147.3
# 143  104.6
# 86    76.3

# %%
model=LinearRegression()
model.fit(tv_train,sales_train)
pred=model.predict(tv_test)

# %%
sales_test
# Out:
# 58     23.8
# 40     16.6
# 34     11.9
# 102    19.8
# 184    17.6
# 198    25.5
# 95     16.9
# 4      17.9
# 29     10.5
# 168    17.1
# 171    17.5
# 18     11.3
# 11     17.4
# 89     16.7
# 110    18.4
# 118    15.9
# 159    12.9
# 35     17.8
# 136     9.5
# 59     18.4
# 51     10.7
# 16     12.5
# 44      8.5
# 94     11.5
# 31     11.9
# 162    19.9
# 38     10.1
# 28     18.9
# 193    19.6
# 27     20.9
# 47     23.2
# 165    16.9
# 194    17.3
# 177    16.7
# 176    20.2
# 97     20.5
# 174    16.5
# 73     11.0
# 69     22.3
# 172     7.6
# Name: Sales, dtype: float64

# %%
model.score(tv_train,sales_train)
# plt.plot(sales_test,pred,color='b')
# Out:
# 0.8209857741497648

# %%
model.score(tv_test,sales_test)
# Out:
# 0.7706807174770673

# %%
plt.scatter(tv_test,sales_test)
plt.plot(tv_test,model.predict(tv_test),color="black")

# %%
error=[]
error=(model.predict(tv_test)/tv_test)*100
li=["data", "predict", "error"]
tab=pd.DataFrame([tv_test, model.predict(tv_test), error],li)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 2
#       1 error=[]
# ----> 2 error=(model.predict(tv_test)/tv_test)*100
#       3 li=["data", "predict", "error"]
#       4 tab=pd.DataFrame([tv_test, model.predict(tv_test), error],li)
#
# File c:\Users\a\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:2113, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2109 @final
#    2110 def __array_ufunc__(
#    2111     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112 ):
# -> 2113     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File c:\Users\a\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:265, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     262     return result
# ...
